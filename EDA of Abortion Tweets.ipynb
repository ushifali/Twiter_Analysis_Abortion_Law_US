# %% [markdown]
# <a href="https://colab.research.google.com/github/ushifali/Twiter_Analysis_Abortion_Law_US/blob/main/EDA%20of%20Abortion%20Tweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


#STEP 1
#View The Data 1
train_data1 = pd.read_csv(
    'Dataset of Roe v. Wade Tweets, Labeled by Abortion Stance.csv')
pd.set_option('max_colwidth', 800)
print(train_data1.head())
# Out:
#       worker_id                               task_id  \
# 0  R7XYZ4FKMFF9  b2d6b83d-b7f0-48e4-b051-c52714e7729e
# 1  Z6J69GNZYEXY  d04db379-b187-4b28-bc00-d92a39b63cf7
# 2  FQG6KZ9NADDZ  929e86cf-b119-4e49-a94f-e36214ab26a7
# 3  T3RMAEPRMD6J  1a62cd41-f8a6-4229-a31f-9ae0329f4e93
# 4  T3RMAEPRMD6J  1f2c8722-1e4d-43ac-9545-19a09a9a2006
#
#                        task_response_id             tweet_id  \
# 0  0006f2e1-6a94-43f5-95a7-3b3d703876a5  1540795996602376192
# 1  0008e3c2-6539-4145-a43a-623c730fbc28  1540794042274828290
# 2  0022694c-7bd0-4d38-9346-13b19c408699  1540795699033509893
# 3  00332386-1046-4caa-ac85-008b4eda19aa  1540795884715261952
# 4  0094922a-34dc-4afd-a627-053d546d0fc0  1540796020023508992
#
#                                                                                                                                            text  \
# ...

# %%
#View the tweets speciffically
print(train_data1['text'])
# Out:
# 0       fb friend went off on me when the draft leaked for suggesting "pro choice" people were way more ready to help peopl… https://t.co/g8cxGUDizO
# 1       roe v wade was just the first domino to fall, they’re after brown v board next, then gay marriage, and they will  c… https://t.co/iXck6yTeid
# 2               Love the Roe V Wade  decision. Now maybe all you abortionist will move back to your home state and let Texas respect and enjoy life.
# 3       If a woman wants an abortion, she should have that right. The argument that a person should only have one because t… https://t.co/xE5T9wzo05
# 4       Alternative proposal: cover travel expenses for @VanderbiltU employees who need abortions, as have many other emplo… https://t.co/blWtRXc8sO
#                                                                             ...
# 1020    I feel like I shouldn't have to say this, but abortion access isn't just for women. It is for transmen and nonbinar… https://t.co/7FPeD0RhBa
# ...

# %%
#checking for missing values
print('\nMissing values percentage')
print(train_data1.isnull().sum() * 100 / len(train_data1))

print('\nMissing values counts')
print(train_data1.isnull().sum())
# Out:
# Missing values percentage
# worker_id                0.000000
# task_id                  0.000000
# task_response_id         0.000000
# tweet_id                 0.000000
# text                     0.000000
# username                 0.000000
# bio                     15.512195
# Categorize the tweet     0.000000
# dtype: float64
#
# Missing values counts
# worker_id                 0
# task_id                   0
# task_response_id          0
# tweet_id                  0
# text                      0
# username                  0
# bio                     159
# Categorize the tweet      0
# dtype: int64

# %%
#Viewing Data 2
train_data2 = pd.read_csv(
    'Abortion data from dataset.csv')
print(train_data2.head())
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                                                              text  \
# 0                        we remind ourselves that love means to be willing to give until it hurts - Mother Teresa
# 1         @user @user and most Islanders have different definitions of "timely access". #irony #peipoli #peivotes
# 2  Life is #precious & so are babies, mothers, & fathers. Please support the sanctity of Human Life. Think #SemST
# 3                                                       @user too many people are taking this to seriously #SemST
# 4                                   Dude i won a #freeshirt from @user ! I never win anything lol #Abort73 #SemST
#
#    label Categorize the tweet
# 0      1             Pro-life
# 1      0              neutral
# 2      1             Pro-life
# 3      0              neutral
# 4      0              neutral

# %%
#View the tweets speciffically
print(train_data2['text'])
# Out:
# 0                                               we remind ourselves that love means to be willing to give until it hurts - Mother Teresa
# 1                                @user @user and most Islanders have different definitions of "timely access". #irony #peipoli #peivotes
# 2                         Life is #precious & so are babies, mothers, & fathers. Please support the sanctity of Human Life. Think #SemST
# 3                                                                              @user too many people are taking this to seriously #SemST
# 4                                                          Dude i won a #freeshirt from @user ! I never win anything lol #Abort73 #SemST
#                                                                      ...
# 582                  @user i don't follow the news, is there a new law that ALL gay people have to get married? I'm against that! #SemST
# ...

# %%
merged=train_data1.append(train_data2)
print(merged)
# Out:
#         worker_id                               task_id  \
# 0    R7XYZ4FKMFF9  b2d6b83d-b7f0-48e4-b051-c52714e7729e
# 1    Z6J69GNZYEXY  d04db379-b187-4b28-bc00-d92a39b63cf7
# 2    FQG6KZ9NADDZ  929e86cf-b119-4e49-a94f-e36214ab26a7
# 3    T3RMAEPRMD6J  1a62cd41-f8a6-4229-a31f-9ae0329f4e93
# 4    T3RMAEPRMD6J  1f2c8722-1e4d-43ac-9545-19a09a9a2006
# ..            ...                                   ...
# 582           NaN                                   NaN
# 583           NaN                                   NaN
# 584           NaN                                   NaN
# 585           NaN                                   NaN
# 586           NaN                                   NaN
#
#                          task_response_id      tweet_id  \
# 0    0006f2e1-6a94-43f5-95a7-3b3d703876a5  1.540796e+18
# 1    0008e3c2-6539-4145-a43a-623c730fbc28  1.540794e+18
# 2    0022694c-7bd0-4d38-9346-13b19c408699  1.540796e+18
# 3    00332386-1046-4caa-ac85-008b4eda19aa  1.540796e+18
# ...

# %%
merged.to_csv('Final Dataset.csv')

# %%
train_data = pd.read_csv('Final Dataset.csv')
print(train_data.head())
# Out:
#    Unnamed: 0     worker_id                               task_id  \
# 0           0  R7XYZ4FKMFF9  b2d6b83d-b7f0-48e4-b051-c52714e7729e
# 1           1  Z6J69GNZYEXY  d04db379-b187-4b28-bc00-d92a39b63cf7
# 2           2  FQG6KZ9NADDZ  929e86cf-b119-4e49-a94f-e36214ab26a7
# 3           3  T3RMAEPRMD6J  1a62cd41-f8a6-4229-a31f-9ae0329f4e93
# 4           4  T3RMAEPRMD6J  1f2c8722-1e4d-43ac-9545-19a09a9a2006
#
#                        task_response_id      tweet_id  \
# 0  0006f2e1-6a94-43f5-95a7-3b3d703876a5  1.540796e+18
# 1  0008e3c2-6539-4145-a43a-623c730fbc28  1.540794e+18
# 2  0022694c-7bd0-4d38-9346-13b19c408699  1.540796e+18
# 3  00332386-1046-4caa-ac85-008b4eda19aa  1.540796e+18
# 4  0094922a-34dc-4afd-a627-053d546d0fc0  1.540796e+18
#
#                                                                                                                                            text  \
# ...

# %%
#check and remove unwanted data columns

# %%
train_data.columns
# Out:
# Index(['Unnamed: 0', 'worker_id', 'task_id', 'task_response_id', 'tweet_id',
#        'text', 'username', 'bio', 'Categorize the tweet', 'Unnamed: 0.1',
#        'label'],
#       dtype='object')

# %%
train_data.drop([ 'worker_id', 'task_id', 'task_response_id', 'tweet_id',], axis=1, inplace=True)

# %%
train_data.columns
# Out:
# Index(['Unnamed: 0', 'text', 'username', 'bio', 'Categorize the tweet',
#        'Unnamed: 0.1', 'label'],
#       dtype='object')

# %%
train_data.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1, inplace=True)

# %%
train_data.columns
# Out:
# Index(['text', 'username', 'bio', 'Categorize the tweet', 'label'], dtype='object')

# %%
#checking for missing values
print('\nMissing values percentage')
print(train_data.isnull().sum() * 100 / len(train_data))

print('\nMissing values counts')
print(train_data.isnull().sum())
# Out:
# Missing values percentage
# text                     0.000000
# username                36.414392
# bio                     46.277916
# Categorize the tweet     0.000000
# label                   63.585608
# dtype: float64
#
# Missing values counts
# text                       0
# username                 587
# bio                      746
# Categorize the tweet       0
# label                   1025
# dtype: int64

# %%
#According to dataset 2, label already we classified so we can drop it
train_data.drop('label', axis=1, inplace=True)

# %%
#STEP 2
#Remove Punctions ans stopwords
# %pip install nltk
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

print(stopwords.words('english'))


stop_words = set(stopwords.words('english'))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# import string library function for punctuation
import string 

# import Regular Expression 
import re 

#function to clean text removing stopwords
def clean_text(text):

    #remove single characters

    #so i have no idea what this tag is propbably from db it appended so im manully removing it
    text = re.sub('#SemST', '', text) 
    text = re.sub('@User|@user', '', text) 
    text = ' '.join( [word for word in text.split() if len(word)>1] )
    text = str(text).lower()    
    text = re.sub(r"https:(\/\/t\.co\/([A-Za-z0-9]|[A-Za-z]){10})", "", text)
    pat = r"[{}]".format(string.punctuation) 
    text = re.sub(pat, '', text) 
    text = re.sub('  +', '', text)     
    text = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*','', text)
    text = re.sub(r'http\S+', '', text)
    text = re.sub('@\.', '', text)    
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text) 
    
    # remove stopwords
    text = ' '.join([word for word in text.split() if word not in stop_words])

    #remove single characters
    text = ' '.join([word for word in text.split() if len(word) > 1] )
    text = re.sub('\s*\\b([a-z]|[a-z]{2})\\b', '', text)
    #to remove single secial characters
    text = re.sub('\?|\.|\!|\/|\;|\:|\'|\+|\-|\*|\"', '', text)
    text = re.sub('’|“|”', '', text)
    return text
#ALSO IN THIS FUNCTION IM PRETTY SURE MANY ARE REPEATED. NOT GONNA CHCEK WHICH IS OBSELETE

# %%
print(train_data['text'].values[0])
print('-'*100)
print(clean_text(train_data['text'].values[0]))


train_data['clean'] = train_data['text'].apply(lambda row: clean_text(row))
train_data.head()
# Out:
# fb friend went off on me when the draft leaked for suggesting "pro choice" people were way more ready to help peopl… https://t.co/g8cxGUDizO
# ----------------------------------------------------------------------------------------------------
#  friend went draft leaked suggesting pro choice people way ready help peopl…
#                                                                                                                                            text  \
# 0  fb friend went off on me when the draft leaked for suggesting "pro choice" people were way more ready to help peopl… https://t.co/g8cxGUDizO
# 1  roe v wade was just the first domino to fall, they’re after brown v board next, then gay marriage, and they will  c… https://t.co/iXck6yTeid
# 2          Love the Roe V Wade  decision. Now maybe all you abortionist will move back to your home state and let Texas respect and enjoy life.
# ...

# %%
train_data.tail()
# Out:
#                                                                                                                                    text  \
# 1607                @user i don't follow the news, is there a new law that ALL gay people have to get married? I'm against that! #SemST
# 1608                   @user The Gods #Law, the #Truth, is being #supressed! They thing they are eternal! #gaymarriage #LoveWins #SemST
# 1609      @user Great job on @user #Scotus should have been eliminated 41 years ago when they called for the murder of children. #SemST
# 1610                                                 @user More #blacks killed by abortion than during #slavery #ConfederateFlag #SemST
# 1611  @user No, U want 2 limit the doctor's choice & force him/her to help w/ abortions. I want to protect life & human dignity. #SemST
#
#      username  bio Categorize the tweet  \
# 1607      NaN  NaN              neutral
# 1608      NaN  NaN              neutral
# ...

# %%
#STEP 3
#LEMMANTIZE IT
# Now we will tokenize our cleaned sentences and then tag each word with POS - tagging. It is necessary for lemmatization
# In corpus linguistics, part-of-speech tagging (POS tagging or PoS tagging or POST), also called grammatical tagging 
# is the process of marking up a word in a text (corpus) as corresponding to a particular part of speech.

import nltk
nltk.download('punkt')

import nltk
nltk.download('averaged_perceptron_tagger')

from nltk.tokenize import word_tokenize

train_data['tokenized'] = train_data['clean'].apply(lambda row: word_tokenize(row))
train_data['pos_tags'] = train_data['tokenized'].apply(lambda row: nltk.tag.pos_tag(row))
train_data.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
#                                                                                                                                            text  \
# 0  fb friend went off on me when the draft leaked for suggesting "pro choice" people were way more ready to help peopl… https://t.co/g8cxGUDizO
# 1  roe v wade was just the first domino to fall, they’re after brown v board next, then gay marriage, and they will  c… https://t.co/iXck6yTeid
# 2          Love the Roe V Wade  decision. Now maybe all you abortionist will move back to your home state and let Texas respect and enjoy life.
# ...

# %% [markdown]
# ```
# For refernce
#
# CC coordinating conjunction
# CD cardinal digit
# DT determiner
# EX existential there (like: "there is" ... think of it like "there exists")
# FW foreign word
# IN preposition/subordinating conjunction
# JJ adjective 'big'
# JJR adjective, comparative 'bigger'
# JJS adjective, superlative 'biggest'
# LS list marker 1)
# MD modal could, will
# NN noun, singular 'desk'
# NNS noun plural 'desks'
# NNP proper noun, singular 'Harrison'
# NNPS proper noun, plural 'Americans'
# PDT predeterminer 'all the kids'
# POS possessive ending parent's
# PRP personal pronoun I, he, she
# PRP$ possessive pronoun my, his, hers
# RB adverb very, silently,
# RBR adverb, comparative better
# RBS adverb, superlative best
# RP particle give up
# TO to go 'to' the store.
# UH interjection errrrrrrrm
# VB verb, base form take
# VBD verb, past tense took
# VBG verb, gerund/present participle taking
# VBN verb, past participle taken
# VBP verb, sing. present, non-3d take
# VBZ verb, 3rd person sing. present takes
# WDT wh-determiner which
# WP wh-pronoun who, what
# WP$ possessive wh-pronoun whose
# WRB wh-abverb where, when
# ```

# %%
#USING wordnet tags
#https://stackoverflow.com/questions/15586721/wordnet-lemmatization-and-pos-tagging-in-python
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import wordnet

def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        morphy_tag = {'NN':'n', 'JJ':'a','VB':'v', 'RB':'r'}
        try:
          return morphy_tag[treebank_tag[:2]]
        except:
          return 'n' 

    
train_data['wordnet_pos'] = train_data['pos_tags'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) 
                                                               for (word, pos_tag) in x])
train_data.head()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                                                                                                                            text  \
# 0  fb friend went off on me when the draft leaked for suggesting "pro choice" people were way more ready to help peopl… https://t.co/g8cxGUDizO
# 1  roe v wade was just the first domino to fall, they’re after brown v board next, then gay marriage, and they will  c… https://t.co/iXck6yTeid
# 2          Love the Roe V Wade  decision. Now maybe all you abortionist will move back to your home state and let Texas respect and enjoy life.
# 3  If a woman wants an abortion, she should have that right. The argument that a person should only have one because t… https://t.co/xE5T9wzo05
# ...

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()

train_data['lemmatized'] = train_data['wordnet_pos'].apply(lambda x : [wnl.lemmatize(word, tag) for word, tag in x])

train_data.head()
# Out:
#                                                                                                                                            text  \
# 0  fb friend went off on me when the draft leaked for suggesting "pro choice" people were way more ready to help peopl… https://t.co/g8cxGUDizO
# 1  roe v wade was just the first domino to fall, they’re after brown v board next, then gay marriage, and they will  c… https://t.co/iXck6yTeid
# 2          Love the Roe V Wade  decision. Now maybe all you abortionist will move back to your home state and let Texas respect and enjoy life.
# 3  If a woman wants an abortion, she should have that right. The argument that a person should only have one because t… https://t.co/xE5T9wzo05
# 4  Alternative proposal: cover travel expenses for @VanderbiltU employees who need abortions, as have many other emplo… https://t.co/blWtRXc8sO
#
#           username  \
# 0  JQAForPresident
# 1      Jacobskatee
# 2      SBOROBERSON
# 3          seputa_
# ...

# %%
#https://stackoverflow.com/questions/50992974/nltk-wordnetlemmatizer-not-lemmatizing-as-expected
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

x= train_data['Categorize the tweet'].value_counts()

labels = x.keys().tolist()
values = x.tolist()

plt.figure(figsize=(7,5), tight_layout=True)
colors = sns.color_palette('pastel')
plt.bar(labels, values, color=colors[:3],width = 0.5)
plt.xlabel('Opinion',fontweight ='bold')
plt.ylabel('Number of people',fontweight ='bold')
plt.title('Barplot suggesting opinion',fontweight ='bold', pad = 5)
plt.show()

# %%
# create list of all words. This is not vocabulary, because we want to calculate frequency of each word
words = []
for w in train_data['lemmatized'].values:
    words+=w

# %%
from nltk.probability import FreqDist
from wordcloud import WordCloud
import matplotlib.pyplot as plt
  
mostcommon = FreqDist(words).most_common(500)

wordcloud = WordCloud(width=1000, height=500, background_color='white').generate(str(mostcommon))
fig = plt.figure(figsize=(20,6), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top 100 Most Common Words', fontsize=35,y = 1)
plt.tight_layout(pad=2)
plt.show()

# %%
train_data['lemmatized'] = train_data['lemmatized'].apply(lambda row: ' '.join(row))
train_data.head()
# Out:
#                                                                                                                                            text  \
# 0  fb friend went off on me when the draft leaked for suggesting "pro choice" people were way more ready to help peopl… https://t.co/g8cxGUDizO
# 1  roe v wade was just the first domino to fall, they’re after brown v board next, then gay marriage, and they will  c… https://t.co/iXck6yTeid
# 2          Love the Roe V Wade  decision. Now maybe all you abortionist will move back to your home state and let Texas respect and enjoy life.
# 3  If a woman wants an abortion, she should have that right. The argument that a person should only have one because t… https://t.co/xE5T9wzo05
# 4  Alternative proposal: cover travel expenses for @VanderbiltU employees who need abortions, as have many other emplo… https://t.co/blWtRXc8sO
#
#           username  \
# 0  JQAForPresident
# 1      Jacobskatee
# 2      SBOROBERSON
# 3          seputa_
# ...

# %%
def plot_freq(words, freqs, sentiment):
    plt.figure(figsize=(20,4), tight_layout=True)
    colors = sns.color_palette('pastel')
    plt.bar(words, freqs,color=colors[:25])    
    plt.xlabel('words',fontweight ='bold')
    plt.ylabel('frequency of words',fontweight ='bold')
    plt.title(f'Frequency of 25 most common words for {sentiment} sentiment', fontsize=20,fontweight ='bold')
    plt.yticks(fontsize=5)
    plt.xticks(rotation=60, fontsize=8)
    plt.show()

# %%
from collections import Counter
group_by = train_data.groupby('Categorize the tweet')['lemmatized'].apply(lambda x: Counter(' '.join(x).split()).most_common(50))

print(group_by)

words = [list(zip(*group_by.iloc[i]))[0] for i in range(3)]
freqs = [list(zip(*group_by.iloc[i]))[1] for i in range(3)]

plot_freq(words[0], freqs[0], 'Pro-Choice')
print("\n")
plot_freq(words[1], freqs[1], 'Pro-life')
print("\n")
plot_freq(words[2], freqs[2], 'neutral')
# Out:
# Categorize the tweet
# Pro-choice                [(roe, 281), (abortion, 265), (wade, 256), (right, 138), (woman, 132), (overturn, 121), (people, 69), (get, 59), (say, 55), (know, 50), (court, 46), (want, 45), (make, 44), (state, 44), (think, 44), (supreme, 40), (one, 38), (like, 37), (need, 36), (support, 34), (decision, 34), (would, 34), (take, 33), (don, 32), (dont, 32), (life, 29), (pregnant, 29), (body, 27), (amp, 27), (choice, 27), (men, 26), (back, 25), (vote, 25), (law, 24), (baby, 24), (still, 23), (go, 22), (many, 22), (live, 22), (scotus, 22), (ban, 20), (can, 20), (even, 20), (codify, 19), (thing, 19), (never, 19), (pro, 19), (youre, 18), (fuck, 18), (tell, 18)]
# ...

# %%
mostcommon = FreqDist(words[0]).most_common(500)

wordcloud = WordCloud(width=1000, height=500, background_color='black').generate(str(mostcommon))
fig = plt.figure(figsize=(20,6), facecolor='black')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('WordCloud for Pro-Choice Tweets', fontsize=35,color='white',y=1.12)
plt.tight_layout(pad=5)
plt.show()

# %%
mostcommon = FreqDist(words[1]).most_common(500)

wordcloud = WordCloud(width=1000, height=500, background_color='black').generate(str(mostcommon))
fig = plt.figure(figsize=(20,6), facecolor='black')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('WordCloud for Pro-Life Tweets', fontsize=35,color='white',y=1.12)
plt.tight_layout(pad=5)
plt.show()

# %%
mostcommon = FreqDist(words[2]).most_common(500)

wordcloud = WordCloud(width=1000, height=500, background_color='black').generate(str(mostcommon))
fig = plt.figure(figsize=(20,6), facecolor='black')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('WordCloud for Neutral Tweets', fontsize=35,color='white',y=1.12)
plt.tight_layout(pad=5)
plt.show()
